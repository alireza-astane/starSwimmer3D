# %%
from Swimmer import *
import numpy as np
plt.rc('text', usetex=True)
import matplotlib
matplotlib.rcParams.update({'font.size': 16})

# %% [markdown]
# ## Initialization

# %%
T=1
R=1
a = 10*R
epsilons = np.linspace(0.1,5,50)*R

steps = 1000
nsteps = 1000
dt = T/steps

r0 = np.array([[0, 0, 0],
[0, 0, a],
[a*np.sqrt(8)/3, 0 , -a/3],
[-a*np.sqrt(8)/6, a*np.sqrt(24)/6 , -a/3],
[-a*np.sqrt(8)/6, -a*np.sqrt(24)/6, -a/3]])

# %% [markdown]
# ### Saving Data for epsilon = 3

# %%
# start checking 1  
stepData = np.zeros((4,4,3))
#steps = 10_000_000
epsilon = 3
w = epsilon/T
closing  = a - np.arange(steps+1)*epsilon/steps
opening = a - epsilon + np.arange(steps+1)*epsilon/steps
opened = a *np.ones(steps+1)
closed = (a-epsilon)*np.ones(steps+1)
    

totalRotation = np.eye(3)
totalDelta = 0

rf1,delta,Rotation=  act(np.array([closing,opened,opened,opened]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf2,delta,Rotation=  act(np.array([closed,closing,opened,opened]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf3,delta,Rotation=  act(np.array([closed,closed,closing,opened]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf4,delta,Rotation=  act(np.array([closed,closed,closed,closing]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf5,delta,Rotation=  act(np.array([opening,closed,closed,closed]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf6,delta,Rotation=  act(np.array([opened,opening,closed,closed]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf7,delta,Rotation=  act(np.array([opened,opened,opening,closed]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf8,delta,Rotation=  act(np.array([opened,opened,opened,opening]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

stepData[0,0,:] = totalDelta
stepData[0,1:4,:] = totalRotation

totalRotation = np.eye(3)
totalDelta = 0

rf1,delta,Rotation=  act(np.array([opened,closing,opened,opened]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf2,delta,Rotation=  act(np.array([opened,closed,closing,opened]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf3,delta,Rotation=  act(np.array([opened,closed,closed,closing]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf4,delta,Rotation=  act(np.array([closing,closed,closed,closed]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf5,delta,Rotation=  act(np.array([closed,opening,closed,closed]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf6,delta,Rotation=  act(np.array([closed,opened,opening,closed]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf7,delta,Rotation=  act(np.array([closed,opened,opened,opening]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf8,delta,Rotation=  act(np.array([opening,opened,opened,opened]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

stepData[1,0,:] = totalDelta
stepData[1,1:4,:] = totalRotation

totalRotation = np.eye(3)
totalDelta = 0

rf1,delta,Rotation=  act(np.array([opened,opened,closing,opened]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf2,delta,Rotation=  act(np.array([opened,opened,closed,closing]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf3,delta,Rotation=  act(np.array([closing,opened,closed,closed]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf4,delta,Rotation=  act(np.array([closed,closing,closed,closed]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf5,delta,Rotation=  act(np.array([closed,closed,opening,closed]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf6,delta,Rotation=  act(np.array([closed,closed,opened,opening]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf7,delta,Rotation=  act(np.array([opening,closed,opened,opened]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf8,delta,Rotation=  act(np.array([opened,opening,opened,opened]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)


stepData[2,0,:] = totalDelta
stepData[2,1:4,:] = totalRotation

totalRotation = np.eye(3)
totalDelta = 0

rf1,delta,Rotation=  act(np.array([opened,opened,opened,closing]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf2,delta,Rotation=  act(np.array([closing,opened,opened,closed]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf3,delta,Rotation=  act(np.array([closed,closing,opened,closed]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf4,delta,Rotation=  act(np.array([closed,closed,closing,closed]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf5,delta,Rotation=  act(np.array([closed,closed,closed,opening]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf6,delta,Rotation=  act(np.array([opening,closed,closed,opened]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf7,delta,Rotation=  act(np.array([opened,opening,closed,opened]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

rf8,delta,Rotation=  act(np.array([opened,opened,opening,opened]))
totalDelta += np.matmul(totalRotation,delta)
totalRotation  = np.matmul(Rotation,totalRotation)

stepData[3,0,:] = totalDelta
stepData[3,1:4,:] = totalRotation




np.save("stepDatasForE=3",stepData)

# %%
stepData = np.load("stepDatasForE=3.npy")

# %%
ax = plt.figure().add_subplot(projection='3d')

plt.title("The effect of rolling the Sequence")
ax.scatter(xs = stepData[:,0,:][:,0] ,ys = stepData[:,0,:][:,1],zs= stepData[:,0,:][:,2])


ax.plot(xs =[stepData[:,0,:][0,0],0], ys = [stepData[:,0,:][0,1],0], zs=[stepData[:,0,:][0,2],0])
ax.plot(xs =[stepData[:,0,:][1,0],0], ys = [stepData[:,0,:][1,1],0], zs=[stepData[:,0,:][1,2],0])
ax.plot(xs =[stepData[:,0,:][2,0],0], ys = [stepData[:,0,:][2,1],0], zs=[stepData[:,0,:][2,2],0])
ax.plot(xs =[stepData[:,0,:][3,0],0], ys = [stepData[:,0,:][3,1],0], zs=[stepData[:,0,:][3,2],0])

# plt.savefig("rollingSequenceEffect.png")




plt.show()

# %% [markdown]
# # Starting Effect

# %%
print(stepData[:,0,:][0])
print(stepData[:,0,:][1])
print(stepData[:,0,:][2])
print(stepData[:,0,:][3])
# Out:
# [-0.01758938 -0.0103273  -0.02455982]
# [-0.01724297 -0.01007012  0.02491356]
# [ 0.02927171 -0.00989964  0.00804763]
# [ 0.00556653  0.03029982 -0.00839832]

# %%
e1,e2,e3,e4 = getStartingEffect(10,3,10000)

# %%
e1p = e1/np.linalg.norm(e1)
e2p = e2/np.linalg.norm(e2)
e3p = e3/np.linalg.norm(e3)
e4p = e4/np.linalg.norm(e4)

# %%
ax = plt.figure().add_subplot(projection='3d')

ax.scatter(xs = [e1p[0],e2p[0],e3p[0],e4p[0]],ys = [e1p[1],e2p[1],e3p[1],e4p[1]], zs=[e1p[2],e2p[2],e3p[2],e4p[2]])


ax.plot(xs =[e1p[0],0], ys = [e1p[1],0], zs=[e1p[2],0])
ax.plot(xs =[e2p[0],0], ys = [e2p[1],0], zs=[e2p[2],0])
ax.plot(xs =[e3p[0],0], ys = [e3p[1],0], zs=[e3p[2],0])
ax.plot(xs =[e4p[0],0], ys = [e4p[1],0], zs=[e4p[2],0])

plt.savefig("4_1.png")

plt.show()

# %%
par = 10

ax = plt.figure().add_subplot(projection='3d')

ax.scatter(xs = par*stepData[:,0,:][:,0] ,ys = par*stepData[:,0,:][:,1],zs= par*stepData[:,0,:][:,2])

ax.plot(xs =[par*stepData[:,0,:][0,0],0], ys = [par*stepData[:,0,:][0,1],0], zs=[par*stepData[:,0,:][0,2],0])
ax.plot(xs =[par*stepData[:,0,:][1,0],0], ys = [par*stepData[:,0,:][1,1],0], zs=[par*stepData[:,0,:][1,2],0])
ax.plot(xs =[par*stepData[:,0,:][2,0],0], ys = [par*stepData[:,0,:][2,1],0], zs=[par*stepData[:,0,:][2,2],0])
ax.plot(xs =[par*stepData[:,0,:][3,0],0], ys = [par*stepData[:,0,:][3,1],0], zs=[par*stepData[:,0,:][3,2],0])

ax.scatter(xs = [e1p[0],e2p[0],e3p[0],e4p[0]],ys = [e1p[1],e2p[1],e3p[1],e4p[1]], zs=[e1p[2],e2p[2],e3p[2],e4p[2]])


ax.plot(xs =[e1p[0],0], ys = [e1p[1],0], zs=[e1p[2],0])
ax.plot(xs =[e2p[0],0], ys = [e2p[1],0], zs=[e2p[2],0])
ax.plot(xs =[e3p[0],0], ys = [e3p[1],0], zs=[e3p[2],0])
ax.plot(xs =[e4p[0],0], ys = [e4p[1],0], zs=[e4p[2],0])



plt.savefig("4_3.png")
plt.show()

# %%
archingData = np.zeros((10000,3))
archingCharacteristicLength = 200
archingSteps = 40
archingPose = np.array([0.,0.,0.])
archingRotation = np.eye(3)
moves = 0
for i in range(archingSteps):
    archingLength = np.random.randint(archingCharacteristicLength)
    sequence = np.random.randint(4)
    stepRotation = stepData[sequence,1:4,:]
    stepDelta = stepData[sequence,0,:]
    #print(stepDelta)
    for j in range(archingLength):
        archingPose += np.matmul(archingRotation,stepDelta)
        archingRotation = np.matmul(stepRotation,archingRotation)
        
        moves += 1
        archingData[moves] = archingPose
        
archingData= archingData[:moves]
        
        
ax = plt.figure().add_subplot(projection='3d')



ax.scatter(xs = archingData[:,0],ys = archingData[:,1], zs=archingData[:,2],s=10)


plt.show()

# %%
archingData = np.zeros((100000,3))
archingCharacteristicLength = 1000
archingSteps = 100
archingPose = np.array([0.,0.,0.])
archingRotation = np.eye(3)
moves = 0
for i in range(archingSteps):
    archingLength = np.random.randint(archingCharacteristicLength)
    sequence = np.random.randint(4)
    stepRotation = stepData[sequence,1:4,:]
    stepDelta = stepData[sequence,0,:]
    #print(stepDelta)
    for j in range(archingLength):
        archingPose += np.matmul(archingRotation,stepDelta)
        archingRotation = np.matmul(stepRotation,archingRotation)
        
        moves += 1
        archingData[moves] = archingPose
        
archingData= archingData[:moves]
        
        
ax = plt.figure(figsize=(10,10)).add_subplot(projection='3d')

ax.scatter(xs = archingData[:,0],ys = archingData[:,1], zs=archingData[:,2],s=1)

plt.savefig("4_2.png")

plt.show()
